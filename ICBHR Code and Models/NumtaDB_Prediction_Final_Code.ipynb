# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import cv2

# %%
model = keras.models.load_model('/content/drive/MyDrive/modelsFinal/numtaDB.keras')

# %% [markdown]
# 3, 4, 8

# %%
import numpy as np
testImgPath = "/content/drive/MyDrive/modelsFinal/predict/3.jpg"
testImg = cv2.imread(testImgPath)
print(plt.imshow(testImg))
print(testImg.shape)
# Out:
# AxesImage(size=(236, 242))
# (236, 242, 3)

# %%
testImg = cv2.resize(testImg,(32,32))
testImg = cv2.cvtColor(testImg,cv2.COLOR_BGR2GRAY)
#testImg = np.expand_dims(testImg, axis=-1)
print(plt.imshow(testImg))
testImg = testImg.reshape(1,32,32,1)
print(testImg.shape)
# Out:
# AxesImage(size=(32, 32))
# (1, 32, 32, 1)

# %%
predicted_class = np.argmax(model.predict(testImg))
print(predicted_class)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 3
